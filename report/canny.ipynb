# %% [markdown]
# # Canny detector for fused_tp0_ch0+ch1_v2

# %%
import numpy as np
import pandas as pd
from utils import load_dataset, aggregate, plot_quantiles, plot_surface, plot_common
import matplotlib.pyplot as plt
from IPython.display import Markdown
from IPython.display import display, Markdown

algorithm = 'canny'
legend = "2048x2048x{n}"
method = 'mpisingle'
pd.set_option('display.max_rows', 10000)
data = load_dataset('csv', 'canny_fused_tp0')

def aggregate(data, stat, aggfunc):
    maxes = data[(data['stat'] == stat) & (data['method'] == method)].pivot_table('time_ms', columns=['size'], index=['round'], aggfunc='max')
    return maxes.reset_index().melt(id_vars=['round'], value_name='time_ms').pivot_table('time_ms', columns=['size'], aggfunc=aggfunc)
# Out:
# Dataset dimension not found in filename
# Dataset dimension not found in filename

# %% [markdown]
# ## reading the dataset

# %%
read_ds = (data[(data['stat'] == 'read') & (data['method'] == 'mpisingle')]['time_ms'] / 1000)
plt.boxplot(read_ds)
plt.xticks([1], ["read"])
plt.ylabel('time [s]')
plt.savefig(f"figures/canny/read_boxplot.pdf")
read_ds.describe()
read_ds.quantile([0.05, 0.50, 0.95])
# Out:
# 0.05    10.60300
# 0.50    10.73800
# 0.95    11.20775
# Name: time_ms, dtype: float64

# %%
with open('csv/canny_fused_tp0_ch0+ch1_v2_mpisingle.csv') as f:
    ops = list(dict.fromkeys([i.split(',')[0] for i in f]))
for stat in ops:
    p2, p5, p8 = [(aggregate(data, stat, lambda x: x.quantile(q))/1000).T for q in [0.2, 0.5, 0.8]]
    if p2.empty:
        continue
    display(Markdown("# " + stat))

    for c in [p2, p5, p8]:
        table = pd.DataFrame({
            'time_s': c['time_ms'],
            'speedup': (c.T[1] / c)['time_ms']
        })
        table.index.rename('ranks', inplace=True)
        display(table)
        print(table.to_latex())
    
    plt.plot(p5, marker='o')
    plt.fill_between(p5.index, p8['time_ms'], p2['time_ms'], alpha=0.5)
    plt.ylabel('time [s]')
    plt.xlabel('ranks')
    plt.savefig(f"figures/canny/time_{stat}.pdf")
    plt.show()
    
    (p5.T[1] / p5).plot(marker='o')
    plt.plot([1, 2, 4, 6, 8], [1, 2, 4, 6, 8], marker='o')
    plt.ylabel('speedup')
    plt.xlabel('ranks')
    plt.legend(labels=['MPI enabled Op', 'ideal'])
    plt.savefig(f"figures/canny/speedup_{stat}.pdf")
    plt.show()
# Out:
# # read
#         time_s   speedup
# ranks
# 1      10.6438  1.000000
# 2      10.7310  0.991874
# 4      10.7136  0.993485
# 6      10.7658  0.988668
# 8      10.7618  0.989035
# \begin{tabular}{lrr}
# \toprule
# {} &   time\_s &   speedup \\
# ranks &          &           \\
# \midrule
# 1     &  10.6438 &  1.000000 \\
# 2     &  10.7310 &  0.991874 \\
# 4     &  10.7136 &  0.993485 \\
# 6     &  10.7658 &  0.988668 \\
# 8     &  10.7618 &  0.989035 \\
# \bottomrule
# \end{tabular}
#         time_s   speedup
# ranks
# 1      10.6920  1.000000
# 2      10.7485  0.994743
# 4      10.7710  0.992665
# 6      10.7805  0.991791
# 8      10.8100  0.989084
# \begin{tabular}{lrr}
# \toprule
# {} &   time\_s &   speedup \\
# ranks &          &           \\
# \midrule
# 1     &  10.6920 &  1.000000 \\
# 2     &  10.7485 &  0.994743 \\
# 4     &  10.7710 &  0.992665 \\
# 6     &  10.7805 &  0.991791 \\
# 8     &  10.8100 &  0.989084 \\
# \bottomrule
# \end{tabular}
#         time_s   speedup
# ranks
# 1      10.9112  1.000000
# 2      10.8768  1.003163
# 4      10.8786  1.002997
# 6      10.8964  1.001358
# 8      11.2220  0.972304
# \begin{tabular}{lrr}
# \toprule
# {} &   time\_s &   speedup \\
# ranks &          &           \\
# \midrule
# 1     &  10.9112 &  1.000000 \\
# 2     &  10.8768 &  1.003163 \\
# 4     &  10.8786 &  1.002997 \\
# 6     &  10.8964 &  1.001358 \\
# 8     &  11.2220 &  0.972304 \\
# \bottomrule
# \end{tabular}
# # convert.rgb2grayscale;net.imagej.ops.create.img.CreateImgFromDimsAndType
#        time_s   speedup
# ranks
# 1      0.1808  1.000000
# 2      0.1870  0.966845
# 4      0.1896  0.953586
# 6      0.1910  0.946597
# 8      0.1946  0.929085
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.1808 &  1.000000 \\
# 2     &  0.1870 &  0.966845 \\
# 4     &  0.1896 &  0.953586 \\
# 6     &  0.1910 &  0.946597 \\
# 8     &  0.1946 &  0.929085 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      0.1835  1.000000
# 2      0.1945  0.943445
# 4      0.1950  0.941026
# 6      0.1960  0.936224
# 8      0.2010  0.912935
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.1835 &  1.000000 \\
# 2     &  0.1945 &  0.943445 \\
# 4     &  0.1950 &  0.941026 \\
# 6     &  0.1960 &  0.936224 \\
# 8     &  0.2010 &  0.912935 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      0.1864  1.000000
# 2      0.1988  0.937626
# 4      0.1990  0.936683
# 6      0.2010  0.927363
# 8      0.2062  0.903977
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.1864 &  1.000000 \\
# 2     &  0.1988 &  0.937626 \\
# 4     &  0.1990 &  0.936683 \\
# 6     &  0.2010 &  0.927363 \\
# 8     &  0.2062 &  0.903977 \\
# \bottomrule
# \end{tabular}
# # convert.rgb2grayscale;cz.it4i.scijava.mpi.ops.parallel.Parallel;cz.it4i.scijava.mpi.ops.parallel.ThreadedParallel
#         time_s   speedup
# ranks
# 1      12.3912  1.000000
# 2       6.3128  1.962869
# 4       3.1926  3.881225
# 6       2.1734  5.701298
# 8       1.6564  7.480802
# \begin{tabular}{lrr}
# \toprule
# {} &   time\_s &   speedup \\
# ranks &          &           \\
# \midrule
# 1     &  12.3912 &  1.000000 \\
# 2     &   6.3128 &  1.962869 \\
# 4     &   3.1926 &  3.881225 \\
# 6     &   2.1734 &  5.701298 \\
# 8     &   1.6564 &  7.480802 \\
# \bottomrule
# \end{tabular}
#         time_s   speedup
# ranks
# 1      12.5140  1.000000
# 2       6.3655  1.965910
# 4       3.2070  3.902089
# 6       2.1930  5.706338
# 8       1.6630  7.524955
# \begin{tabular}{lrr}
# \toprule
# {} &   time\_s &   speedup \\
# ranks &          &           \\
# \midrule
# 1     &  12.5140 &  1.000000 \\
# 2     &   6.3655 &  1.965910 \\
# 4     &   3.2070 &  3.902089 \\
# 6     &   2.1930 &  5.706338 \\
# 8     &   1.6630 &  7.524955 \\
# \bottomrule
# \end{tabular}
#         time_s   speedup
# ranks
# 1      12.5872  1.000000
# 2       6.3916  1.969335
# 4       3.2326  3.893832
# 6       2.2066  5.704342
# 8       1.7098  7.361797
# \begin{tabular}{lrr}
# \toprule
# {} &   time\_s &   speedup \\
# ranks &          &           \\
# \midrule
# 1     &  12.5872 &  1.000000 \\
# 2     &   6.3916 &  1.969335 \\
# 4     &   3.2326 &  3.893832 \\
# 6     &   2.2066 &  5.704342 \\
# 8     &   1.7098 &  7.361797 \\
# \bottomrule
# \end{tabular}
# # convert.rgb2grayscale;cz.it4i.scijava.mpi.ops.parallel.Parallel;barrier
#        time_s  speedup
# ranks
# 1      0.0000      NaN
# 2      0.0500      0.0
# 4      0.0700      0.0
# 6      0.1108      0.0
# 8      0.1228      0.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &  0.0000 &      NaN \\
# 2     &  0.0500 &      0.0 \\
# 4     &  0.0700 &      0.0 \\
# 6     &  0.1108 &      0.0 \\
# 8     &  0.1228 &      0.0 \\
# \bottomrule
# \end{tabular}
#        time_s  speedup
# ranks
# 1      0.0000      NaN
# 2      0.0830      0.0
# 4      0.1030      0.0
# 6      0.1275      0.0
# 8      0.1410      0.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &  0.0000 &      NaN \\
# 2     &  0.0830 &      0.0 \\
# 4     &  0.1030 &      0.0 \\
# 6     &  0.1275 &      0.0 \\
# 8     &  0.1410 &      0.0 \\
# \bottomrule
# \end{tabular}
#        time_s  speedup
# ranks
# 1      0.0000      NaN
# 2      0.1492      0.0
# 4      0.1204      0.0
# 6      0.1500      0.0
# 8      0.1570      0.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &  0.0000 &      NaN \\
# 2     &  0.1492 &      0.0 \\
# 4     &  0.1204 &      0.0 \\
# 6     &  0.1500 &      0.0 \\
# 8     &  0.1570 &      0.0 \\
# \bottomrule
# \end{tabular}
# # convert.rgb2grayscale;cz.it4i.scijava.mpi.ops.parallel.Parallel;gather
#        time_s   speedup
# ranks
# 1      0.1234  1.000000
# 2      0.1830  0.674317
# 4      0.2062  0.598448
# 6      0.2408  0.512458
# 8      0.2788  0.442611
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.1234 &  1.000000 \\
# 2     &  0.1830 &  0.674317 \\
# 4     &  0.2062 &  0.598448 \\
# 6     &  0.2408 &  0.512458 \\
# 8     &  0.2788 &  0.442611 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      0.1245  1.000000
# 2      0.1865  0.667560
# 4      0.2125  0.585882
# 6      0.2665  0.467167
# 8      0.2875  0.433043
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.1245 &  1.000000 \\
# 2     &  0.1865 &  0.667560 \\
# 4     &  0.2125 &  0.585882 \\
# 6     &  0.2665 &  0.467167 \\
# 8     &  0.2875 &  0.433043 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      0.1302  1.000000
# 2      0.1928  0.675311
# 4      0.2318  0.561691
# 6      0.2720  0.478676
# 8      0.3224  0.403846
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.1302 &  1.000000 \\
# 2     &  0.1928 &  0.675311 \\
# 4     &  0.2318 &  0.561691 \\
# 6     &  0.2720 &  0.478676 \\
# 8     &  0.3224 &  0.403846 \\
# \bottomrule
# \end{tabular}
# # convert.rgb2grayscale;cz.it4i.scijava.mpi.ops.parallel.Parallel
#         time_s   speedup
# ranks
# 1      12.5228  1.000000
# 2       6.5526  1.911119
# 4       3.5114  3.566327
# 6       2.5978  4.820540
# 8       2.1528  5.816983
# \begin{tabular}{lrr}
# \toprule
# {} &   time\_s &   speedup \\
# ranks &          &           \\
# \midrule
# 1     &  12.5228 &  1.000000 \\
# 2     &   6.5526 &  1.911119 \\
# 4     &   3.5114 &  3.566327 \\
# 6     &   2.5978 &  4.820540 \\
# 8     &   2.1528 &  5.816983 \\
# \bottomrule
# \end{tabular}
#         time_s   speedup
# ranks
# 1      12.6540  1.000000
# 2       6.6085  1.914807
# 4       3.5420  3.572558
# 6       2.6325  4.806838
# 8       2.1800  5.804587
# \begin{tabular}{lrr}
# \toprule
# {} &   time\_s &   speedup \\
# ranks &          &           \\
# \midrule
# 1     &  12.6540 &  1.000000 \\
# 2     &   6.6085 &  1.914807 \\
# 4     &   3.5420 &  3.572558 \\
# 6     &   2.6325 &  4.806838 \\
# 8     &   2.1800 &  5.804587 \\
# \bottomrule
# \end{tabular}
#         time_s   speedup
# ranks
# 1      12.7178  1.000000
# 2       6.6622  1.908949
# 4       3.5996  3.533115
# 6       2.6696  4.763935
# 8       2.1970  5.788712
# \begin{tabular}{lrr}
# \toprule
# {} &   time\_s &   speedup \\
# ranks &          &           \\
# \midrule
# 1     &  12.7178 &  1.000000 \\
# 2     &   6.6622 &  1.908949 \\
# 4     &   3.5996 &  3.533115 \\
# 6     &   2.6696 &  4.763935 \\
# 8     &   2.1970 &  5.788712 \\
# \bottomrule
# \end{tabular}
# # convert.rgb2grayscale
#         time_s   speedup
# ranks
# 1      12.7448  1.000000
# 2       6.8274  1.866714
# 4       3.8058  3.348783
# 6       2.9126  4.375747
# 8       2.5050  5.087745
# \begin{tabular}{lrr}
# \toprule
# {} &   time\_s &   speedup \\
# ranks &          &           \\
# \midrule
# 1     &  12.7448 &  1.000000 \\
# 2     &   6.8274 &  1.866714 \\
# 4     &   3.8058 &  3.348783 \\
# 6     &   2.9126 &  4.375747 \\
# 8     &   2.5050 &  5.087745 \\
# \bottomrule
# \end{tabular}
#         time_s   speedup
# ranks
# 1      12.8810  1.000000
# 2       6.8670  1.875783
# 4       3.8355  3.358363
# 6       2.9475  4.370144
# 8       2.5175  5.116584
# \begin{tabular}{lrr}
# \toprule
# {} &   time\_s &   speedup \\
# ranks &          &           \\
# \midrule
# 1     &  12.8810 &  1.000000 \\
# 2     &   6.8670 &  1.875783 \\
# 4     &   3.8355 &  3.358363 \\
# 6     &   2.9475 &  4.370144 \\
# 8     &   2.5175 &  5.116584 \\
# \bottomrule
# \end{tabular}
#         time_s   speedup
# ranks
# 1      12.9354  1.000000
# 2       6.9228  1.868521
# 4       3.8692  3.343172
# 6       2.9924  4.322751
# 8       2.5464  5.079877
# \begin{tabular}{lrr}
# \toprule
# {} &   time\_s &   speedup \\
# ranks &          &           \\
# \midrule
# 1     &  12.9354 &  1.000000 \\
# 2     &   6.9228 &  1.868521 \\
# 4     &   3.8692 &  3.343172 \\
# 6     &   2.9924 &  4.322751 \\
# 8     &   2.5464 &  5.079877 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Convert.Float64;net.imagej.ops.Ops.Create.Img;net.imagej.ops.Ops.Create.ImgFactory
#        time_s  speedup
# ranks
# 1       0.001      1.0
# 2       0.001      1.0
# 4       0.001      1.0
# 6       0.001      1.0
# 8       0.001      1.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &   0.001 &      1.0 \\
# 2     &   0.001 &      1.0 \\
# 4     &   0.001 &      1.0 \\
# 6     &   0.001 &      1.0 \\
# 8     &   0.001 &      1.0 \\
# \bottomrule
# \end{tabular}
#        time_s  speedup
# ranks
# 1       0.001      1.0
# 2       0.001      1.0
# 4       0.001      1.0
# 6       0.001      1.0
# 8       0.001      1.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &   0.001 &      1.0 \\
# 2     &   0.001 &      1.0 \\
# 4     &   0.001 &      1.0 \\
# 6     &   0.001 &      1.0 \\
# 8     &   0.001 &      1.0 \\
# \bottomrule
# \end{tabular}
#        time_s  speedup
# ranks
# 1       0.001      1.0
# 2       0.001      1.0
# 4       0.001      1.0
# 6       0.001      1.0
# 8       0.001      1.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &   0.001 &      1.0 \\
# 2     &   0.001 &      1.0 \\
# 4     &   0.001 &      1.0 \\
# 6     &   0.001 &      1.0 \\
# 8     &   0.001 &      1.0 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Convert.Float64;net.imagej.ops.Ops.Create.Img
#        time_s   speedup
# ranks
# 1      0.5080  1.000000
# 2      0.5762  0.881638
# 4      0.5970  0.850921
# 6      0.6204  0.818827
# 8      0.6422  0.791031
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.5080 &  1.000000 \\
# 2     &  0.5762 &  0.881638 \\
# 4     &  0.5970 &  0.850921 \\
# 6     &  0.6204 &  0.818827 \\
# 8     &  0.6422 &  0.791031 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      0.5890  1.000000
# 2      0.6000  0.981667
# 4      0.6195  0.950767
# 6      0.6485  0.908250
# 8      0.6825  0.863004
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.5890 &  1.000000 \\
# 2     &  0.6000 &  0.981667 \\
# 4     &  0.6195 &  0.950767 \\
# 6     &  0.6485 &  0.908250 \\
# 8     &  0.6825 &  0.863004 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      0.6192  1.000000
# 2      0.6128  1.010444
# 4      0.6344  0.976040
# 6      0.6622  0.935065
# 8      0.7156  0.865288
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.6192 &  1.000000 \\
# 2     &  0.6128 &  1.010444 \\
# 4     &  0.6344 &  0.976040 \\
# 6     &  0.6622 &  0.935065 \\
# 8     &  0.7156 &  0.865288 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Convert.Float64;cz.it4i.scijava.mpi.ops.parallel.Parallel;cz.it4i.scijava.mpi.ops.parallel.ThreadedParallel
#        time_s   speedup
# ranks
# 1      4.6392  1.000000
# 2      2.3088  2.009356
# 4      0.9288  4.994832
# 6      0.6464  7.176980
# 8      0.5030  9.223062
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  4.6392 &  1.000000 \\
# 2     &  2.3088 &  2.009356 \\
# 4     &  0.9288 &  4.994832 \\
# 6     &  0.6464 &  7.176980 \\
# 8     &  0.5030 &  9.223062 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      4.6655  1.000000
# 2      2.3300  2.002361
# 4      0.9340  4.995182
# 6      0.6490  7.188752
# 8      0.5075  9.193103
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  4.6655 &  1.000000 \\
# 2     &  2.3300 &  2.002361 \\
# 4     &  0.9340 &  4.995182 \\
# 6     &  0.6490 &  7.188752 \\
# 8     &  0.5075 &  9.193103 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      4.7096  1.000000
# 2      2.3782  1.980321
# 4      0.9672  4.869313
# 6      0.6638  7.094908
# 8      0.5114  9.209230
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  4.7096 &  1.000000 \\
# 2     &  2.3782 &  1.980321 \\
# 4     &  0.9672 &  4.869313 \\
# 6     &  0.6638 &  7.094908 \\
# 8     &  0.5114 &  9.209230 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Convert.Float64;cz.it4i.scijava.mpi.ops.parallel.Parallel;barrier
#        time_s  speedup
# ranks
# 1      0.0000      NaN
# 2      0.0496      0.0
# 4      0.0834      0.0
# 6      0.1414      0.0
# 8      0.2552      0.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &  0.0000 &      NaN \\
# 2     &  0.0496 &      0.0 \\
# 4     &  0.0834 &      0.0 \\
# 6     &  0.1414 &      0.0 \\
# 8     &  0.2552 &      0.0 \\
# \bottomrule
# \end{tabular}
#        time_s  speedup
# ranks
# 1      0.0000      NaN
# 2      0.1035      0.0
# 4      0.1125      0.0
# 6      0.2400      0.0
# 8      0.3020      0.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &  0.0000 &      NaN \\
# 2     &  0.1035 &      0.0 \\
# 4     &  0.1125 &      0.0 \\
# 6     &  0.2400 &      0.0 \\
# 8     &  0.3020 &      0.0 \\
# \bottomrule
# \end{tabular}
#        time_s  speedup
# ranks
# 1      0.0000      NaN
# 2      0.1366      0.0
# 4      0.1686      0.0
# 6      0.2836      0.0
# 8      0.3604      0.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &  0.0000 &      NaN \\
# 2     &  0.1366 &      0.0 \\
# 4     &  0.1686 &      0.0 \\
# 6     &  0.2836 &      0.0 \\
# 8     &  0.3604 &      0.0 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Convert.Float64;cz.it4i.scijava.mpi.ops.parallel.Parallel;gather
#        time_s   speedup
# ranks
# 1      0.9932  1.000000
# 2      1.2466  0.796727
# 4      1.2946  0.767187
# 6      1.7288  0.574503
# 8      1.9100  0.520000
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.9932 &  1.000000 \\
# 2     &  1.2466 &  0.796727 \\
# 4     &  1.2946 &  0.767187 \\
# 6     &  1.7288 &  0.574503 \\
# 8     &  1.9100 &  0.520000 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      1.0175  1.000000
# 2      1.4060  0.723684
# 4      1.3225  0.769376
# 6      1.7905  0.568277
# 8      1.9485  0.522197
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  1.0175 &  1.000000 \\
# 2     &  1.4060 &  0.723684 \\
# 4     &  1.3225 &  0.769376 \\
# 6     &  1.7905 &  0.568277 \\
# 8     &  1.9485 &  0.522197 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      1.0530  1.000000
# 2      1.5232  0.691308
# 4      1.3346  0.789000
# 6      1.8276  0.576165
# 8      2.0034  0.525606
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  1.0530 &  1.000000 \\
# 2     &  1.5232 &  0.691308 \\
# 4     &  1.3346 &  0.789000 \\
# 6     &  1.8276 &  0.576165 \\
# 8     &  2.0034 &  0.525606 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Convert.Float64;cz.it4i.scijava.mpi.ops.parallel.Parallel
#        time_s   speedup
# ranks
# 1      5.6560  1.000000
# 2      3.7642  1.502577
# 4      2.3676  2.388917
# 6      2.4920  2.269663
# 8      2.5526  2.215780
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  5.6560 &  1.000000 \\
# 2     &  3.7642 &  1.502577 \\
# 4     &  2.3676 &  2.388917 \\
# 6     &  2.4920 &  2.269663 \\
# 8     &  2.5526 &  2.215780 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      5.6970  1.000000
# 2      3.8470  1.480894
# 4      2.3865  2.387178
# 6      2.5290  2.252669
# 8      2.5740  2.213287
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  5.6970 &  1.000000 \\
# 2     &  3.8470 &  1.480894 \\
# 4     &  2.3865 &  2.387178 \\
# 6     &  2.5290 &  2.252669 \\
# 8     &  2.5740 &  2.213287 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      5.7508  1.000000
# 2      3.8786  1.482700
# 4      2.4266  2.369900
# 6      2.5832  2.226231
# 8      2.7150  2.118158
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  5.7508 &  1.000000 \\
# 2     &  3.8786 &  1.482700 \\
# 4     &  2.4266 &  2.369900 \\
# 6     &  2.5832 &  2.226231 \\
# 8     &  2.7150 &  2.118158 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Convert.Float64
#        time_s   speedup
# ranks
# 1      6.2586  1.000000
# 2      4.4146  1.417705
# 4      3.0206  2.071972
# 6      3.1166  2.008150
# 8      3.1766  1.970220
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  6.2586 &  1.000000 \\
# 2     &  4.4146 &  1.417705 \\
# 4     &  3.0206 &  2.071972 \\
# 6     &  3.1166 &  2.008150 \\
# 8     &  3.1766 &  1.970220 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      6.3240  1.000000
# 2      4.4770  1.412553
# 4      3.0435  2.077871
# 6      3.1720  1.993695
# 8      3.2470  1.947644
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  6.3240 &  1.000000 \\
# 2     &  4.4770 &  1.412553 \\
# 4     &  3.0435 &  2.077871 \\
# 6     &  3.1720 &  1.993695 \\
# 8     &  3.2470 &  1.947644 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      6.3854  1.000000
# 2      4.5116  1.415329
# 4      3.0810  2.072509
# 6      3.2464  1.966917
# 8      3.3246  1.920652
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  6.3854 &  1.000000 \\
# 2     &  4.5116 &  1.415329 \\
# 4     &  3.0810 &  2.072509 \\
# 6     &  3.2464 &  1.966917 \\
# 8     &  3.3246 &  1.920652 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Create.Kernel;net.imagej.ops.Ops.Create.ImgFactory
#        time_s  speedup
# ranks
# 1       0.001      1.0
# 2       0.001      1.0
# 4       0.001      1.0
# 6       0.001      1.0
# 8       0.001      1.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &   0.001 &      1.0 \\
# 2     &   0.001 &      1.0 \\
# 4     &   0.001 &      1.0 \\
# 6     &   0.001 &      1.0 \\
# 8     &   0.001 &      1.0 \\
# \bottomrule
# \end{tabular}
#        time_s  speedup
# ranks
# 1       0.001      1.0
# 2       0.001      1.0
# 4       0.001      1.0
# 6       0.001      1.0
# 8       0.001      1.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &   0.001 &      1.0 \\
# 2     &   0.001 &      1.0 \\
# 4     &   0.001 &      1.0 \\
# 6     &   0.001 &      1.0 \\
# 8     &   0.001 &      1.0 \\
# \bottomrule
# \end{tabular}
#        time_s  speedup
# ranks
# 1       0.001      1.0
# 2       0.001      1.0
# 4       0.001      1.0
# 6       0.001      1.0
# 8       0.001      1.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &   0.001 &      1.0 \\
# 2     &   0.001 &      1.0 \\
# 4     &   0.001 &      1.0 \\
# 6     &   0.001 &      1.0 \\
# 8     &   0.001 &      1.0 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Create.Kernel
#        time_s   speedup
# ranks
# 1      0.0110  1.000000
# 2      0.0080  1.375000
# 4      0.0498  0.220884
# 6      0.0294  0.374150
# 8      0.0258  0.426357
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.0110 &  1.000000 \\
# 2     &  0.0080 &  1.375000 \\
# 4     &  0.0498 &  0.220884 \\
# 6     &  0.0294 &  0.374150 \\
# 8     &  0.0258 &  0.426357 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      0.0125  1.000000
# 2      0.0185  0.675676
# 4      0.0525  0.238095
# 6      0.0395  0.316456
# 8      0.0395  0.316456
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.0125 &  1.000000 \\
# 2     &  0.0185 &  0.675676 \\
# 4     &  0.0525 &  0.238095 \\
# 6     &  0.0395 &  0.316456 \\
# 8     &  0.0395 &  0.316456 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      0.0132  1.000000
# 2      0.0290  0.455172
# 4      0.0544  0.242647
# 6      0.0450  0.293333
# 8      0.0474  0.278481
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.0132 &  1.000000 \\
# 2     &  0.0290 &  0.455172 \\
# 4     &  0.0544 &  0.242647 \\
# 6     &  0.0450 &  0.293333 \\
# 8     &  0.0474 &  0.278481 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Create.Img
#        time_s   speedup
# ranks
# 1      0.4704  1.000000
# 2      0.5478  0.858708
# 4      0.5510  0.853721
# 6      0.5888  0.798913
# 8      0.6006  0.783217
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.4704 &  1.000000 \\
# 2     &  0.5478 &  0.858708 \\
# 4     &  0.5510 &  0.853721 \\
# 6     &  0.5888 &  0.798913 \\
# 8     &  0.6006 &  0.783217 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      0.5040  1.000000
# 2      0.5610  0.898396
# 4      0.5740  0.878049
# 6      0.6090  0.827586
# 8      0.6195  0.813559
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.5040 &  1.000000 \\
# 2     &  0.5610 &  0.898396 \\
# 4     &  0.5740 &  0.878049 \\
# 6     &  0.6090 &  0.827586 \\
# 8     &  0.6195 &  0.813559 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      0.5768  1.000000
# 2      0.5970  0.966164
# 4      0.6008  0.960053
# 6      0.6374  0.904926
# 8      0.6260  0.921406
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.5768 &  1.000000 \\
# 2     &  0.5970 &  0.966164 \\
# 4     &  0.6008 &  0.960053 \\
# 6     &  0.6374 &  0.904926 \\
# 8     &  0.6260 &  0.921406 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Filter.Convolve;net.imagej.ops.Ops.Filter.Convolve;convolution;cz.it4i.scijava.mpi.ops.parallel.Parallel;cz.it4i.scijava.mpi.ops.parallel.ThreadedParallel
#          time_s   speedup
# ranks
# 1      279.5232  1.000000
# 2      141.7576  1.971839
# 4       72.2506  3.868801
# 6       48.1432  5.806079
# 8       36.1430  7.733813
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  279.5232 &  1.000000 \\
# 2     &  141.7576 &  1.971839 \\
# 4     &   72.2506 &  3.868801 \\
# 6     &   48.1432 &  5.806079 \\
# 8     &   36.1430 &  7.733813 \\
# \bottomrule
# \end{tabular}
#          time_s   speedup
# ranks
# 1      281.7950  1.000000
# 2      147.9930  1.904110
# 4       74.1675  3.799440
# 6       49.3880  5.705738
# 8       37.3040  7.554016
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  281.7950 &  1.000000 \\
# 2     &  147.9930 &  1.904110 \\
# 4     &   74.1675 &  3.799440 \\
# 6     &   49.3880 &  5.705738 \\
# 8     &   37.3040 &  7.554016 \\
# \bottomrule
# \end{tabular}
#          time_s   speedup
# ranks
# 1      285.9140  1.000000
# 2      150.0086  1.905984
# 4       74.6888  3.828071
# 6       50.2772  5.686753
# 8       37.5014  7.624089
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  285.9140 &  1.000000 \\
# 2     &  150.0086 &  1.905984 \\
# 4     &   74.6888 &  3.828071 \\
# 6     &   50.2772 &  5.686753 \\
# 8     &   37.5014 &  7.624089 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Filter.Convolve;net.imagej.ops.Ops.Filter.Convolve;convolution;cz.it4i.scijava.mpi.ops.parallel.Parallel;barrier
#        time_s  speedup
# ranks
# 1      0.0000      NaN
# 2      1.8338      0.0
# 4      2.5810      0.0
# 6      2.2868      0.0
# 8      2.6100      0.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &  0.0000 &      NaN \\
# 2     &  1.8338 &      0.0 \\
# 4     &  2.5810 &      0.0 \\
# 6     &  2.2868 &      0.0 \\
# 8     &  2.6100 &      0.0 \\
# \bottomrule
# \end{tabular}
#        time_s  speedup
# ranks
# 1      0.0000      NaN
# 2      5.3450      0.0
# 4      4.0375      0.0
# 6      3.4140      0.0
# 8      3.1605      0.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &  0.0000 &      NaN \\
# 2     &  5.3450 &      0.0 \\
# 4     &  4.0375 &      0.0 \\
# 6     &  3.4140 &      0.0 \\
# 8     &  3.1605 &      0.0 \\
# \bottomrule
# \end{tabular}
#        time_s  speedup
# ranks
# 1      0.0000      NaN
# 2      8.3500      0.0
# 4      4.8288      0.0
# 6      4.6004      0.0
# 8      3.7790      0.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &  0.0000 &      NaN \\
# 2     &  8.3500 &      0.0 \\
# 4     &  4.8288 &      0.0 \\
# 6     &  4.6004 &      0.0 \\
# 8     &  3.7790 &      0.0 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Filter.Convolve;net.imagej.ops.Ops.Filter.Convolve;convolution;cz.it4i.scijava.mpi.ops.parallel.Parallel;gather
#        time_s   speedup
# ranks
# 1      0.9384  1.000000
# 2      1.3658  0.687070
# 4      1.5174  0.618426
# 6      1.9624  0.478190
# 8      2.0548  0.456687
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.9384 &  1.000000 \\
# 2     &  1.3658 &  0.687070 \\
# 4     &  1.5174 &  0.618426 \\
# 6     &  1.9624 &  0.478190 \\
# 8     &  2.0548 &  0.456687 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      0.9570  1.000000
# 2      1.4220  0.672996
# 4      1.5785  0.606272
# 6      2.0335  0.470617
# 8      2.1490  0.445323
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.9570 &  1.000000 \\
# 2     &  1.4220 &  0.672996 \\
# 4     &  1.5785 &  0.606272 \\
# 6     &  2.0335 &  0.470617 \\
# 8     &  2.1490 &  0.445323 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      0.9922  1.000000
# 2      1.4624  0.678474
# 4      1.6480  0.602063
# 6      2.1106  0.470103
# 8      2.2204  0.446856
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.9922 &  1.000000 \\
# 2     &  1.4624 &  0.678474 \\
# 4     &  1.6480 &  0.602063 \\
# 6     &  2.1106 &  0.470103 \\
# 8     &  2.2204 &  0.446856 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Filter.Convolve;net.imagej.ops.Ops.Filter.Convolve;convolution;cz.it4i.scijava.mpi.ops.parallel.Parallel
#          time_s   speedup
# ranks
# 1      280.4600  1.000000
# 2      143.1998  1.958522
# 4       73.8550  3.797441
# 6       50.3864  5.566185
# 8       38.3880  7.305929
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  280.4600 &  1.000000 \\
# 2     &  143.1998 &  1.958522 \\
# 4     &   73.8550 &  3.797441 \\
# 6     &   50.3864 &  5.566185 \\
# 8     &   38.3880 &  7.305929 \\
# \bottomrule
# \end{tabular}
#          time_s   speedup
# ranks
# 1      282.7480  1.000000
# 2      149.4625  1.891765
# 4       75.8155  3.729422
# 6       51.0005  5.544024
# 8       39.4700  7.163618
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  282.7480 &  1.000000 \\
# 2     &  149.4625 &  1.891765 \\
# 4     &   75.8155 &  3.729422 \\
# 6     &   51.0005 &  5.544024 \\
# 8     &   39.4700 &  7.163618 \\
# \bottomrule
# \end{tabular}
#          time_s   speedup
# ranks
# 1      286.8860  1.000000
# 2      151.6258  1.892066
# 4       76.3768  3.756193
# 6       52.0180  5.515129
# 8       39.8712  7.195319
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  286.8860 &  1.000000 \\
# 2     &  151.6258 &  1.892066 \\
# 4     &   76.3768 &  3.756193 \\
# 6     &   52.0180 &  5.515129 \\
# 8     &   39.8712 &  7.195319 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Filter.Convolve;net.imagej.ops.Ops.Filter.Convolve;convolution
#          time_s   speedup
# ranks
# 1      280.4612  1.000000
# 2      143.2010  1.958514
# 4       73.9038  3.794950
# 6       50.3900  5.565811
# 8       38.3898  7.305618
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  280.4612 &  1.000000 \\
# 2     &  143.2010 &  1.958514 \\
# 4     &   73.9038 &  3.794950 \\
# 6     &   50.3900 &  5.565811 \\
# 8     &   38.3898 &  7.305618 \\
# \bottomrule
# \end{tabular}
#          time_s   speedup
# ranks
# 1      282.7490  1.000000
# 2      149.4635  1.891760
# 4       75.8325  3.728599
# 6       51.0035  5.543718
# 8       39.4980  7.158565
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  282.7490 &  1.000000 \\
# 2     &  149.4635 &  1.891760 \\
# 4     &   75.8325 &  3.728599 \\
# 6     &   51.0035 &  5.543718 \\
# 8     &   39.4980 &  7.158565 \\
# \bottomrule
# \end{tabular}
#          time_s   speedup
# ranks
# 1      286.8870  1.000000
# 2      151.6278  1.892048
# 4       76.4124  3.754456
# 6       52.0256  5.514343
# 8       39.8780  7.194117
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  286.8870 &  1.000000 \\
# 2     &  151.6278 &  1.892048 \\
# 4     &   76.4124 &  3.754456 \\
# 6     &   52.0256 &  5.514343 \\
# 8     &   39.8780 &  7.194117 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Filter.Convolve;net.imagej.ops.Ops.Filter.Convolve
#          time_s   speedup
# ranks
# 1      280.4652  1.000000
# 2      143.2062  1.958471
# 4       73.9582  3.792212
# 6       50.3964  5.565183
# 8       38.3956  7.304618
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  280.4652 &  1.000000 \\
# 2     &  143.2062 &  1.958471 \\
# 4     &   73.9582 &  3.792212 \\
# 6     &   50.3964 &  5.565183 \\
# 8     &   38.3956 &  7.304618 \\
# \bottomrule
# \end{tabular}
#          time_s   speedup
# ranks
# 1      282.7535  1.000000
# 2      149.4690  1.891720
# 4       75.8545  3.727577
# 6       51.0085  5.543262
# 8       39.5295  7.152974
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  282.7535 &  1.000000 \\
# 2     &  149.4690 &  1.891720 \\
# 4     &   75.8545 &  3.727577 \\
# 6     &   51.0085 &  5.543262 \\
# 8     &   39.5295 &  7.152974 \\
# \bottomrule
# \end{tabular}
#          time_s   speedup
# ranks
# 1      286.8918  1.000000
# 2      151.6326  1.892019
# 4       76.4272  3.753792
# 6       52.0634  5.510432
# 8       39.8960  7.190992
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  286.8918 &  1.000000 \\
# 2     &  151.6326 &  1.892019 \\
# 4     &   76.4272 &  3.753792 \\
# 6     &   52.0634 &  5.510432 \\
# 8     &   39.8960 &  7.190992 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Filter.Convolve
#          time_s   speedup
# ranks
# 1      280.4712  1.000000
# 2      143.2124  1.958428
# 4       74.0048  3.789906
# 6       50.4342  5.561131
# 8       38.4026  7.303443
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  280.4712 &  1.000000 \\
# 2     &  143.2124 &  1.958428 \\
# 4     &   74.0048 &  3.789906 \\
# 6     &   50.4342 &  5.561131 \\
# 8     &   38.4026 &  7.303443 \\
# \bottomrule
# \end{tabular}
#          time_s   speedup
# ranks
# 1      282.7595  1.000000
# 2      149.4755  1.891678
# 4       75.8795  3.726428
# 6       51.0145  5.542728
# 8       39.5975  7.140842
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  282.7595 &  1.000000 \\
# 2     &  149.4755 &  1.891678 \\
# 4     &   75.8795 &  3.726428 \\
# 6     &   51.0145 &  5.542728 \\
# 8     &   39.5975 &  7.140842 \\
# \bottomrule
# \end{tabular}
#          time_s   speedup
# ranks
# 1      286.8980  1.000000
# 2      151.6386  1.891985
# 4       76.4444  3.753028
# 6       52.0694  5.509916
# 8       39.9456  7.182218
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  286.8980 &  1.000000 \\
# 2     &  151.6386 &  1.891985 \\
# 4     &   76.4444 &  3.753028 \\
# 6     &   52.0694 &  5.509916 \\
# 8     &   39.9456 &  7.182218 \\
# \bottomrule
# \end{tabular}
# # edgeDetector;net.imagej.ops.Ops.Create.Kernel;net.imagej.ops.Ops.Create.ImgFactory
#        time_s  speedup
# ranks
# 1      0.0000      NaN
# 2      0.0000      NaN
# 4      0.0000      NaN
# 6      0.0000      NaN
# 8      0.0008      0.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &  0.0000 &      NaN \\
# 2     &  0.0000 &      NaN \\
# 4     &  0.0000 &      NaN \\
# 6     &  0.0000 &      NaN \\
# 8     &  0.0008 &      0.0 \\
# \bottomrule
# \end{tabular}
#        time_s  speedup
# ranks
# 1      0.0000      NaN
# 2      0.0010      0.0
# 4      0.0010      0.0
# 6      0.0005      0.0
# 8      0.0010      0.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &  0.0000 &      NaN \\
# 2     &  0.0010 &      0.0 \\
# 4     &  0.0010 &      0.0 \\
# 6     &  0.0005 &      0.0 \\
# 8     &  0.0010 &      0.0 \\
# \bottomrule
# \end{tabular}
#        time_s  speedup
# ranks
# 1      0.0002      1.0
# 2      0.0010      0.2
# 4      0.0010      0.2
# 6      0.0010      0.2
# 8      0.0010      0.2
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &  0.0002 &      1.0 \\
# 2     &  0.0010 &      0.2 \\
# 4     &  0.0010 &      0.2 \\
# 6     &  0.0010 &      0.2 \\
# 8     &  0.0010 &      0.2 \\
# \bottomrule
# \end{tabular}
# # edgeDetector;net.imagej.ops.Ops.Create.Kernel
#        time_s   speedup
# ranks
# 1      0.0040  1.000000
# 2      0.0050  0.800000
# 4      0.0300  0.133333
# 6      0.0304  0.131579
# 8      0.0526  0.076046
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.0040 &  1.000000 \\
# 2     &  0.0050 &  0.800000 \\
# 4     &  0.0300 &  0.133333 \\
# 6     &  0.0304 &  0.131579 \\
# 8     &  0.0526 &  0.076046 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      0.0050  1.000000
# 2      0.0060  0.833333
# 4      0.0405  0.123457
# 6      0.0405  0.123457
# 8      0.0550  0.090909
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.0050 &  1.000000 \\
# 2     &  0.0060 &  0.833333 \\
# 4     &  0.0405 &  0.123457 \\
# 6     &  0.0405 &  0.123457 \\
# 8     &  0.0550 &  0.090909 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      0.0090  1.000000
# 2      0.0228  0.394737
# 4      0.0492  0.182927
# 6      0.0422  0.213270
# 8      0.0804  0.111940
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.0090 &  1.000000 \\
# 2     &  0.0228 &  0.394737 \\
# 4     &  0.0492 &  0.182927 \\
# 6     &  0.0422 &  0.213270 \\
# 8     &  0.0804 &  0.111940 \\
# \bottomrule
# \end{tabular}
# # edgeDetector;net.imagej.ops.Ops.Create.Img
#        time_s   speedup
# ranks
# 1      0.5950  1.000000
# 2      0.5926  1.004050
# 4      0.6072  0.979908
# 6      0.6014  0.989358
# 8      0.6070  0.980231
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.5950 &  1.000000 \\
# 2     &  0.5926 &  1.004050 \\
# 4     &  0.6072 &  0.979908 \\
# 6     &  0.6014 &  0.989358 \\
# 8     &  0.6070 &  0.980231 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1       0.616  1.000000
# 2       0.608  1.013158
# 4       0.613  1.004894
# 6       0.629  0.979332
# 8       0.637  0.967033
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &   0.616 &  1.000000 \\
# 2     &   0.608 &  1.013158 \\
# 4     &   0.613 &  1.004894 \\
# 6     &   0.629 &  0.979332 \\
# 8     &   0.637 &  0.967033 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      0.6382  1.000000
# 2      0.6286  1.015272
# 4      0.6296  1.013659
# 6      0.6374  1.001255
# 8      0.6530  0.977335
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.6382 &  1.000000 \\
# 2     &  0.6286 &  1.015272 \\
# 4     &  0.6296 &  1.013659 \\
# 6     &  0.6374 &  1.001255 \\
# 8     &  0.6530 &  0.977335 \\
# \bottomrule
# \end{tabular}
# # edgeDetector;sobel x;net.imagej.ops.Ops.Filter.Convolve;convolution;cz.it4i.scijava.mpi.ops.parallel.Parallel;cz.it4i.scijava.mpi.ops.parallel.ThreadedParallel
#          time_s   speedup
# ranks
# 1      113.3754  1.000000
# 2       53.5958  2.115378
# 4       28.0868  4.036608
# 6       19.2582  5.887123
# 8       14.7322  7.695755
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  113.3754 &  1.000000 \\
# 2     &   53.5958 &  2.115378 \\
# 4     &   28.0868 &  4.036608 \\
# 6     &   19.2582 &  5.887123 \\
# 8     &   14.7322 &  7.695755 \\
# \bottomrule
# \end{tabular}
#          time_s   speedup
# ranks
# 1      119.6665  1.000000
# 2       59.3775  2.015351
# 4       29.5560  4.048806
# 6       19.5520  6.120422
# 8       15.0060  7.974577
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  119.6665 &  1.000000 \\
# 2     &   59.3775 &  2.015351 \\
# 4     &   29.5560 &  4.048806 \\
# 6     &   19.5520 &  6.120422 \\
# 8     &   15.0060 &  7.974577 \\
# \bottomrule
# \end{tabular}
#          time_s   speedup
# ranks
# 1      120.7346  1.000000
# 2       61.1604  1.974065
# 4       29.7648  4.056288
# 6       19.8520  6.081735
# 8       15.3116  7.885172
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  120.7346 &  1.000000 \\
# 2     &   61.1604 &  1.974065 \\
# 4     &   29.7648 &  4.056288 \\
# 6     &   19.8520 &  6.081735 \\
# 8     &   15.3116 &  7.885172 \\
# \bottomrule
# \end{tabular}
# # edgeDetector;sobel x;net.imagej.ops.Ops.Filter.Convolve;convolution;cz.it4i.scijava.mpi.ops.parallel.Parallel;barrier
#        time_s  speedup
# ranks
# 1      0.0000      NaN
# 2      0.9328      0.0
# 4      2.9286      0.0
# 6      2.2634      0.0
# 8      1.8974      0.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &  0.0000 &      NaN \\
# 2     &  0.9328 &      0.0 \\
# 4     &  2.9286 &      0.0 \\
# 6     &  2.2634 &      0.0 \\
# 8     &  1.8974 &      0.0 \\
# \bottomrule
# \end{tabular}
#        time_s  speedup
# ranks
# 1      0.0000      NaN
# 2      3.0830      0.0
# 4      3.2800      0.0
# 6      2.8240      0.0
# 8      2.2955      0.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &  0.0000 &      NaN \\
# 2     &  3.0830 &      0.0 \\
# 4     &  3.2800 &      0.0 \\
# 6     &  2.8240 &      0.0 \\
# 8     &  2.2955 &      0.0 \\
# \bottomrule
# \end{tabular}
#        time_s  speedup
# ranks
# 1      0.0000      NaN
# 2      5.4002      0.0
# 4      4.1416      0.0
# 6      3.2426      0.0
# 8      2.4964      0.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &  0.0000 &      NaN \\
# 2     &  5.4002 &      0.0 \\
# 4     &  4.1416 &      0.0 \\
# 6     &  3.2426 &      0.0 \\
# 8     &  2.4964 &      0.0 \\
# \bottomrule
# \end{tabular}
# # edgeDetector;sobel x;net.imagej.ops.Ops.Filter.Convolve;convolution;cz.it4i.scijava.mpi.ops.parallel.Parallel;gather
#        time_s   speedup
# ranks
# 1      0.9570  1.000000
# 2      1.3966  0.685236
# 4      1.4516  0.659273
# 6      1.8584  0.514959
# 8      1.9938  0.479988
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.9570 &  1.000000 \\
# 2     &  1.3966 &  0.685236 \\
# 4     &  1.4516 &  0.659273 \\
# 6     &  1.8584 &  0.514959 \\
# 8     &  1.9938 &  0.479988 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1       1.000  1.000000
# 2       1.412  0.708215
# 4       1.485  0.673401
# 6       1.918  0.521376
# 8       2.056  0.486381
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &   1.000 &  1.000000 \\
# 2     &   1.412 &  0.708215 \\
# 4     &   1.485 &  0.673401 \\
# 6     &   1.918 &  0.521376 \\
# 8     &   2.056 &  0.486381 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      1.0484  1.000000
# 2      1.4486  0.723733
# 4      1.5014  0.698282
# 6      1.9568  0.535773
# 8      2.0760  0.505010
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  1.0484 &  1.000000 \\
# 2     &  1.4486 &  0.723733 \\
# 4     &  1.5014 &  0.698282 \\
# 6     &  1.9568 &  0.535773 \\
# 8     &  2.0760 &  0.505010 \\
# \bottomrule
# \end{tabular}
# # edgeDetector;sobel x;net.imagej.ops.Ops.Filter.Convolve;convolution;cz.it4i.scijava.mpi.ops.parallel.Parallel
#          time_s   speedup
# ranks
# 1      114.4242  1.000000
# 2       55.1526  2.074684
# 4       29.8280  3.836134
# 6       21.4650  5.330734
# 8       16.9658  6.744403
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  114.4242 &  1.000000 \\
# 2     &   55.1526 &  2.074684 \\
# 4     &   29.8280 &  3.836134 \\
# 6     &   21.4650 &  5.330734 \\
# 8     &   16.9658 &  6.744403 \\
# \bottomrule
# \end{tabular}
#          time_s   speedup
# ranks
# 1      120.6725  1.000000
# 2       60.8820  1.982072
# 4       31.2450  3.862138
# 6       21.6735  5.567744
# 8       17.2735  6.985990
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  120.6725 &  1.000000 \\
# 2     &   60.8820 &  1.982072 \\
# 4     &   31.2450 &  3.862138 \\
# 6     &   21.6735 &  5.567744 \\
# 8     &   17.2735 &  6.985990 \\
# \bottomrule
# \end{tabular}
#          time_s   speedup
# ranks
# 1      121.7752  1.000000
# 2       62.5746  1.946080
# 4       31.4410  3.873134
# 6       21.8940  5.562035
# 8       17.3702  7.010581
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  121.7752 &  1.000000 \\
# 2     &   62.5746 &  1.946080 \\
# 4     &   31.4410 &  3.873134 \\
# 6     &   21.8940 &  5.562035 \\
# 8     &   17.3702 &  7.010581 \\
# \bottomrule
# \end{tabular}
# # edgeDetector;sobel x;net.imagej.ops.Ops.Filter.Convolve;convolution
#          time_s   speedup
# ranks
# 1      114.4250  1.000000
# 2       55.1536  2.074661
# 4       29.8540  3.832820
# 6       21.4876  5.325164
# 8       16.9714  6.742225
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  114.4250 &  1.000000 \\
# 2     &   55.1536 &  2.074661 \\
# 4     &   29.8540 &  3.832820 \\
# 6     &   21.4876 &  5.325164 \\
# 8     &   16.9714 &  6.742225 \\
# \bottomrule
# \end{tabular}
#          time_s   speedup
# ranks
# 1      120.6730  1.000000
# 2       60.8825  1.982064
# 4       31.2630  3.859930
# 6       21.6750  5.567382
# 8       17.2745  6.985615
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  120.6730 &  1.000000 \\
# 2     &   60.8825 &  1.982064 \\
# 4     &   31.2630 &  3.859930 \\
# 6     &   21.6750 &  5.567382 \\
# 8     &   17.2745 &  6.985615 \\
# \bottomrule
# \end{tabular}
#          time_s   speedup
# ranks
# 1      121.7760  1.000000
# 2       62.5756  1.946062
# 4       31.4896  3.867182
# 6       21.8988  5.560853
# 8       17.4152  6.992512
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  121.7760 &  1.000000 \\
# 2     &   62.5756 &  1.946062 \\
# 4     &   31.4896 &  3.867182 \\
# 6     &   21.8988 &  5.560853 \\
# 8     &   17.4152 &  6.992512 \\
# \bottomrule
# \end{tabular}
# # edgeDetector;sobel x;net.imagej.ops.Ops.Filter.Convolve
#          time_s   speedup
# ranks
# 1      114.4290  1.000000
# 2       55.1576  2.074583
# 4       29.8830  3.829234
# 6       21.5100  5.319805
# 8       16.9802  6.738967
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  114.4290 &  1.000000 \\
# 2     &   55.1576 &  2.074583 \\
# 4     &   29.8830 &  3.829234 \\
# 6     &   21.5100 &  5.319805 \\
# 8     &   16.9802 &  6.738967 \\
# \bottomrule
# \end{tabular}
#          time_s   speedup
# ranks
# 1      120.6770  1.000000
# 2       60.8865  1.981999
# 4       31.2780  3.858207
# 6       21.6790  5.566539
# 8       17.2845  6.981805
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  120.6770 &  1.000000 \\
# 2     &   60.8865 &  1.981999 \\
# 4     &   31.2780 &  3.858207 \\
# 6     &   21.6790 &  5.566539 \\
# 8     &   17.2845 &  6.981805 \\
# \bottomrule
# \end{tabular}
#          time_s   speedup
# ranks
# 1      121.7792  1.000000
# 2       62.5788  1.946014
# 4       31.5406  3.861030
# 6       21.9106  5.558004
# 8       17.4622  6.973875
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  121.7792 &  1.000000 \\
# 2     &   62.5788 &  1.946014 \\
# 4     &   31.5406 &  3.861030 \\
# 6     &   21.9106 &  5.558004 \\
# 8     &   17.4622 &  6.973875 \\
# \bottomrule
# \end{tabular}
# # edgeDetector;sobel x
#          time_s   speedup
# ranks
# 1      114.4298  1.000000
# 2       55.1584  2.074567
# 4       29.9082  3.826034
# 6       21.5108  5.319644
# 8       16.9858  6.736792
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ...
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      5.5646  1.000000
# 2      3.7054  1.501754
# 4      2.6740  2.081002
# 6      2.7418  2.029543
# 8      2.7684  2.010042
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  5.5646 &  1.000000 \\
# 2     &  3.7054 &  1.501754 \\
# 4     &  2.6740 &  2.081002 \\
# 6     &  2.7418 &  2.029543 \\
# 8     &  2.7684 &  2.010042 \\
# \bottomrule
# \end{tabular}
# # edgeDetector;edge_tracking
#         time_s   speedup
# ranks
# 1      12.8234  1.000000
# 2      10.3290  1.241495
# 4       8.9472  1.433231
# 6       9.0052  1.423999
# 8       8.9540  1.432142
# \begin{tabular}{lrr}
# \toprule
# {} &   time\_s &   speedup \\
# ranks &          &           \\
# \midrule
# 1     &  12.8234 &  1.000000 \\
# 2     &  10.3290 &  1.241495 \\
# 4     &   8.9472 &  1.433231 \\
# 6     &   9.0052 &  1.423999 \\
# 8     &   8.9540 &  1.432142 \\
# \bottomrule
# \end{tabular}
#         time_s   speedup
# ranks
# 1      12.9350  1.000000
# 2      10.3795  1.246206
# 4       9.0460  1.429914
# 6       9.0380  1.431179
# 8       9.0195  1.434115
# \begin{tabular}{lrr}
# \toprule
# {} &   time\_s &   speedup \\
# ranks &          &           \\
# \midrule
# 1     &  12.9350 &  1.000000 \\
# 2     &  10.3795 &  1.246206 \\
# 4     &   9.0460 &  1.429914 \\
# 6     &   9.0380 &  1.431179 \\
# 8     &   9.0195 &  1.434115 \\
# \bottomrule
# \end{tabular}
#         time_s   speedup
# ranks
# 1      13.1180  1.000000
# 2      10.5438  1.244143
# 4       9.4140  1.393457
# 6       9.1340  1.436173
# 8       9.1350  1.436015
# \begin{tabular}{lrr}
# \toprule
# {} &   time\_s &   speedup \\
# ranks &          &           \\
# \midrule
# 1     &  13.1180 &  1.000000 \\
# 2     &  10.5438 &  1.244143 \\
# 4     &   9.4140 &  1.393457 \\
# 6     &   9.1340 &  1.436173 \\
# 8     &   9.1350 &  1.436015 \\
# \bottomrule
# \end{tabular}
# # edgeDetector
#          time_s   speedup
# ranks
# 1      318.6382  1.000000
# 2      155.4332  2.050001
# 4       91.0948  3.497875
# 6       70.3836  4.527165
# 8       57.6012  5.531798
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  318.6382 &  1.000000 \\
# 2     &  155.4332 &  2.050001 \\
# 4     &   91.0948 &  3.497875 \\
# 6     &   70.3836 &  4.527165 \\
# 8     &   57.6012 &  5.531798 \\
# \bottomrule
# \end{tabular}
#          time_s   speedup
# ranks
# 1      327.0690  1.000000
# 2      172.7785  1.892996
# 4       94.6990  3.453775
# 6       70.7580  4.622361
# 8       59.2075  5.524114
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  327.0690 &  1.000000 \\
# 2     &  172.7785 &  1.892996 \\
# 4     &   94.6990 &  3.453775 \\
# 6     &   70.7580 &  4.622361 \\
# 8     &   59.2075 &  5.524114 \\
# \bottomrule
# \end{tabular}
#          time_s   speedup
# ranks
# 1      328.4296  1.000000
# 2      174.8430  1.878426
# 4       95.7576  3.429802
# 6       72.0418  4.558876
# 8       59.3344  5.535231
# \begin{tabular}{lrr}
# \toprule
# {} &    time\_s &   speedup \\
# ranks &           &           \\
# \midrule
# 1     &  328.4296 &  1.000000 \\
# 2     &  174.8430 &  1.878426 \\
# 4     &   95.7576 &  3.429802 \\
# 6     &   72.0418 &  4.558876 \\
# 8     &   59.3344 &  5.535231 \\
# \bottomrule
# \end{tabular}
# # math.multiply
#        time_s   speedup
# ranks
# 1      0.3460  1.000000
# 2      0.3858  0.896838
# 4      0.3812  0.907660
# 6      0.3756  0.921193
# 8      0.3890  0.889460
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.3460 &  1.000000 \\
# 2     &  0.3858 &  0.896838 \\
# 4     &  0.3812 &  0.907660 \\
# 6     &  0.3756 &  0.921193 \\
# 8     &  0.3890 &  0.889460 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      0.3570  1.000000
# 2      0.3915  0.911877
# 4      0.3900  0.915385
# 6      0.3995  0.893617
# 8      0.3945  0.904943
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.3570 &  1.000000 \\
# 2     &  0.3915 &  0.911877 \\
# 4     &  0.3900 &  0.915385 \\
# 6     &  0.3995 &  0.893617 \\
# 8     &  0.3945 &  0.904943 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      0.3708  1.000000
# 2      0.4036  0.918731
# 4      0.4164  0.890490
# 6      0.4214  0.879924
# 8      0.4024  0.921471
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.3708 &  1.000000 \\
# 2     &  0.4036 &  0.918731 \\
# 4     &  0.4164 &  0.890490 \\
# 6     &  0.4214 &  0.879924 \\
# 8     &  0.4024 &  0.921471 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Convert.Uint8;net.imagej.ops.Ops.Create.Img;net.imagej.ops.Ops.Create.ImgFactory
#        time_s  speedup
# ranks
# 1         0.0      NaN
# 2         0.0      NaN
# 4         0.0      NaN
# 6         0.0      NaN
# 8         0.0      NaN
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &     0.0 &      NaN \\
# 2     &     0.0 &      NaN \\
# 4     &     0.0 &      NaN \\
# 6     &     0.0 &      NaN \\
# 8     &     0.0 &      NaN \\
# \bottomrule
# \end{tabular}
#        time_s  speedup
# ranks
# 1         0.0      NaN
# 2         0.0      NaN
# 4         0.0      NaN
# 6         0.0      NaN
# 8         0.0      NaN
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &     0.0 &      NaN \\
# 2     &     0.0 &      NaN \\
# 4     &     0.0 &      NaN \\
# 6     &     0.0 &      NaN \\
# 8     &     0.0 &      NaN \\
# \bottomrule
# \end{tabular}
#        time_s  speedup
# ranks
# 1         0.0      NaN
# 2         0.0      NaN
# 4         0.0      NaN
# 6         0.0      NaN
# 8         0.0      NaN
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &     0.0 &      NaN \\
# 2     &     0.0 &      NaN \\
# 4     &     0.0 &      NaN \\
# 6     &     0.0 &      NaN \\
# 8     &     0.0 &      NaN \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Convert.Uint8;net.imagej.ops.Ops.Create.Img
#        time_s   speedup
# ranks
# 1      0.0390  1.000000
# 2      0.0502  0.776892
# 4      0.0570  0.684211
# 6      0.0682  0.571848
# 8      0.0764  0.510471
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.0390 &  1.000000 \\
# 2     &  0.0502 &  0.776892 \\
# 4     &  0.0570 &  0.684211 \\
# 6     &  0.0682 &  0.571848 \\
# 8     &  0.0764 &  0.510471 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      0.0405  1.000000
# 2      0.0570  0.710526
# 4      0.0695  0.582734
# 6      0.0820  0.493902
# 8      0.0860  0.470930
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.0405 &  1.000000 \\
# 2     &  0.0570 &  0.710526 \\
# 4     &  0.0695 &  0.582734 \\
# 6     &  0.0820 &  0.493902 \\
# 8     &  0.0860 &  0.470930 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      0.0690  1.000000
# 2      0.0724  0.953039
# 4      0.0784  0.880102
# 6      0.1012  0.681818
# 8      0.1092  0.631868
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.0690 &  1.000000 \\
# 2     &  0.0724 &  0.953039 \\
# 4     &  0.0784 &  0.880102 \\
# 6     &  0.1012 &  0.681818 \\
# 8     &  0.1092 &  0.631868 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Convert.Uint8;cz.it4i.scijava.mpi.ops.parallel.Parallel;cz.it4i.scijava.mpi.ops.parallel.ThreadedParallel
#        time_s   speedup
# ranks
# 1      4.3362  1.000000
# 2      2.2388  1.936841
# 4      1.1270  3.847560
# 6      0.6974  6.217666
# 8      0.5388  8.047884
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  4.3362 &  1.000000 \\
# 2     &  2.2388 &  1.936841 \\
# 4     &  1.1270 &  3.847560 \\
# 6     &  0.6974 &  6.217666 \\
# 8     &  0.5388 &  8.047884 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      4.4130  1.000000
# 2      2.2405  1.969650
# 4      1.1285  3.910501
# 6      0.7125  6.193684
# 8      0.5620  7.852313
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  4.4130 &  1.000000 \\
# 2     &  2.2405 &  1.969650 \\
# 4     &  1.1285 &  3.910501 \\
# 6     &  0.7125 &  6.193684 \\
# 8     &  0.5620 &  7.852313 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      4.4486  1.000000
# 2      2.2588  1.969453
# 4      1.1338  3.923620
# 6      0.7142  6.228787
# 8      0.5812  7.654164
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  4.4486 &  1.000000 \\
# 2     &  2.2588 &  1.969453 \\
# 4     &  1.1338 &  3.923620 \\
# 6     &  0.7142 &  6.228787 \\
# 8     &  0.5812 &  7.654164 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Convert.Uint8;cz.it4i.scijava.mpi.ops.parallel.Parallel;barrier
#        time_s  speedup
# ranks
# 1      0.0000      NaN
# 2      0.0424      0.0
# 4      0.2030      0.0
# 6      0.8358      0.0
# 8      1.0160      0.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &  0.0000 &      NaN \\
# 2     &  0.0424 &      0.0 \\
# 4     &  0.2030 &      0.0 \\
# 6     &  0.8358 &      0.0 \\
# 8     &  1.0160 &      0.0 \\
# \bottomrule
# \end{tabular}
#        time_s  speedup
# ranks
# 1      0.0000      NaN
# 2      0.0915      0.0
# 4      0.2560      0.0
# 6      0.9160      0.0
# 8      1.1185      0.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &  0.0000 &      NaN \\
# 2     &  0.0915 &      0.0 \\
# 4     &  0.2560 &      0.0 \\
# 6     &  0.9160 &      0.0 \\
# 8     &  1.1185 &      0.0 \\
# \bottomrule
# \end{tabular}
#        time_s  speedup
# ranks
# 1      0.0000      NaN
# 2      0.1276      0.0
# 4      0.4162      0.0
# 6      1.0004      0.0
# 8      1.1384      0.0
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &  speedup \\
# ranks &         &          \\
# \midrule
# 1     &  0.0000 &      NaN \\
# 2     &  0.1276 &      0.0 \\
# 4     &  0.4162 &      0.0 \\
# 6     &  1.0004 &      0.0 \\
# 8     &  1.1384 &      0.0 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Convert.Uint8;cz.it4i.scijava.mpi.ops.parallel.Parallel;gather
#        time_s   speedup
# ranks
# 1      0.1118  1.000000
# 2      0.2576  0.434006
# 4      0.2530  0.441897
# 6      0.3088  0.362047
# 8      0.3238  0.345275
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.1118 &  1.000000 \\
# 2     &  0.2576 &  0.434006 \\
# 4     &  0.2530 &  0.441897 \\
# 6     &  0.3088 &  0.362047 \\
# 8     &  0.3238 &  0.345275 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      0.1365  1.000000
# 2      0.2770  0.492780
# 4      0.2580  0.529070
# 6      0.3125  0.436800
# 8      0.3405  0.400881
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.1365 &  1.000000 \\
# 2     &  0.2770 &  0.492780 \\
# 4     &  0.2580 &  0.529070 \\
# 6     &  0.3125 &  0.436800 \\
# 8     &  0.3405 &  0.400881 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      0.1566  1.000000
# 2      0.2968  0.527628
# 4      0.2714  0.577008
# 6      0.3208  0.488155
# 8      0.3688  0.424620
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  0.1566 &  1.000000 \\
# 2     &  0.2968 &  0.527628 \\
# 4     &  0.2714 &  0.577008 \\
# 6     &  0.3208 &  0.488155 \\
# 8     &  0.3688 &  0.424620 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Convert.Uint8;cz.it4i.scijava.mpi.ops.parallel.Parallel
#        time_s   speedup
# ranks
# 1      4.5140  1.000000
# 2      2.5698  1.756557
# 4      1.6586  2.721572
# 6      1.8508  2.438945
# 8      1.8976  2.378794
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  4.5140 &  1.000000 \\
# 2     &  2.5698 &  1.756557 \\
# 4     &  1.6586 &  2.721572 \\
# 6     &  1.8508 &  2.438945 \\
# 8     &  1.8976 &  2.378794 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      4.5380  1.000000
# 2      2.6110  1.738031
# 4      1.7135  2.648381
# 6      1.9275  2.354345
# 8      1.9940  2.275827
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  4.5380 &  1.000000 \\
# 2     &  2.6110 &  1.738031 \\
# 4     &  1.7135 &  2.648381 \\
# 6     &  1.9275 &  2.354345 \\
# 8     &  1.9940 &  2.275827 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      4.6030  1.000000
# 2      2.6838  1.715105
# 4      1.8722  2.458605
# 6      1.9978  2.304034
# 8      2.0362  2.260583
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  4.6030 &  1.000000 \\
# 2     &  2.6838 &  1.715105 \\
# 4     &  1.8722 &  2.458605 \\
# 6     &  1.9978 &  2.304034 \\
# 8     &  2.0362 &  2.260583 \\
# \bottomrule
# \end{tabular}
# # net.imagej.ops.Ops.Convert.Uint8
#        time_s   speedup
# ranks
# 1      4.5652  1.000000
# 2      2.6476  1.724279
# 4      1.7784  2.567027
# 6      1.9548  2.335380
# 8      1.9912  2.292688
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  4.5652 &  1.000000 \\
# 2     &  2.6476 &  1.724279 \\
# 4     &  1.7784 &  2.567027 \\
# 6     &  1.9548 &  2.335380 \\
# 8     &  1.9912 &  2.292688 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      4.6040  1.000000
# 2      2.6935  1.709300
# 4      1.8230  2.525507
# 6      2.0300  2.267980
# 8      2.0835  2.209743
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  4.6040 &  1.000000 \\
# 2     &  2.6935 &  1.709300 \\
# 4     &  1.8230 &  2.525507 \\
# 6     &  2.0300 &  2.267980 \\
# 8     &  2.0835 &  2.209743 \\
# \bottomrule
# \end{tabular}
#        time_s   speedup
# ranks
# 1      4.6572  1.000000
# 2      2.7664  1.683488
# 4      1.9814  2.350459
# 6      2.1296  2.186890
# 8      2.1786  2.137703
# \begin{tabular}{lrr}
# \toprule
# {} &  time\_s &   speedup \\
# ranks &         &           \\
# \midrule
# 1     &  4.6572 &  1.000000 \\
# 2     &  2.7664 &  1.683488 \\
# 4     &  1.9814 &  2.350459 \\
# 6     &  2.1296 &  2.186890 \\
# 8     &  2.1786 &  2.137703 \\
# \bottomrule
# \end{tabular}
# # write
#         time_s   speedup
# ranks
# 1      14.2036  1.000000
# 2      14.5976  0.973009
# 4      14.4132  0.985458
# 6      14.4920  0.980099
# 8      14.4564  0.982513
# \begin{tabular}{lrr}
# \toprule
# {} &   time\_s &   speedup \\
# ranks &          &           \\
# \midrule
# 1     &  14.2036 &  1.000000 \\
# 2     &  14.5976 &  0.973009 \\
# 4     &  14.4132 &  0.985458 \\
# 6     &  14.4920 &  0.980099 \\
# 8     &  14.4564 &  0.982513 \\
# \bottomrule
# \end{tabular}
#         time_s   speedup
# ranks
# 1      14.5875  1.000000
# 2      14.7325  0.990158
# 4      14.5495  1.002612
# 6      14.6285  0.997197
# 8      14.5100  1.005341
# \begin{tabular}{lrr}
# \toprule
# {} &   time\_s &   speedup \\
# ranks &          &           \\
# \midrule
# 1     &  14.5875 &  1.000000 \\
# 2     &  14.7325 &  0.990158 \\
# 4     &  14.5495 &  1.002612 \\
# 6     &  14.6285 &  0.997197 \\
# 8     &  14.5100 &  1.005341 \\
# \bottomrule
# \end{tabular}
#         time_s   speedup
# ranks
# 1      14.9390  1.000000
# 2      14.8524  1.005831
# 4      14.6748  1.018004
# 6      14.9826  0.997090
# 8      14.6600  1.019031
# \begin{tabular}{lrr}
# \toprule
# {} &   time\_s &   speedup \\
# ranks &          &           \\
# \midrule
# 1     &  14.9390 &  1.000000 \\
# 2     &  14.8524 &  1.005831 \\
# 4     &  14.6748 &  1.018004 \\
# 6     &  14.9826 &  0.997090 \\
# 8     &  14.6600 &  1.019031 \\
# \bottomrule
# \end{tabular}

# %%
with open('csv/canny_fused_tp0_ch0+ch1_v2_mpisingle.csv') as f:
    ops = list(dict.fromkeys([i.split(',')[0] for i in f]))

stats = {
'convert.rgb2grayscale': 'Converting to grayscale',
#'net.imagej.ops.Ops.Convert.Float64': 'net.imagej.ops.Ops.Convert.Float64',
'net.imagej.ops.Ops.Filter.Convolve': 'Removing noise with Gaussian convolution',
'edgeDetector;sobel x': 'Sobel in horizontal direction',
'edgeDetector;gradient': 'Gradient calculation',
'edgeDetector;nonmaximum_supression': 'Non-maximal supression',
'edgeDetector;edge_tracking;net.imagej.ops.Ops.Stats.MinMax': 'Minimum / Maximum',
'edgeDetector;edge_tracking;net.imagej.ops.Ops.Image.Normalize': 'Normalization',
'edgeDetector;edge_tracking': 'Edge tracking hysteresis (non-parallelized)',
'edgeDetector': 'Complete edge detection',
#'math.multiply': 'math.multiply',
#'net.imagej.ops.Ops.Convert.Uint8': 'net.imagej.ops.Ops.Convert.Uint8',
}
    
plt.plot([1, 2, 4, 6, 8], [1, 2, 4, 6, 8], marker='o', label='Ideal')
for stat, label in stats.items():
    p2, p5, p8 = [(aggregate(data, stat, lambda x: x.quantile(q))/1000).T for q in [0.2, 0.5, 0.8]]
 
    for c in [p2, p5, p8]:
        table = pd.DataFrame({
            'time_s': c['time_ms'],
            'speedup': (c.T[1] / c)['time_ms']
        })
        table.index.rename('ranks', inplace=True)
    
    plt.plot(p5.T[1] / p5, marker='o', label=label)
plt.ylabel('speedup')
plt.xlabel('ranks')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.savefig('figures/canny/canny_speedup_overall.pdf', bbox_inches='tight')
plt.show()
